# %%
# %matplotlib inline

from __future__ import division

import re, os, logging, sys, random, json, xml.etree.ElementTree 
from time import time

from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
from sklearn.cross_validation import cross_val_score
from sklearn import metrics
from sklearn.metrics import pairwise_distances

import numpy as np
from scipy.stats import mode
import matplotlib.pyplot as plt, mpld3
from mpld3 import plugins
from click_info import ClickInfo
# mpld3.enable_notebook()

from pprint import pprint
from operator import itemgetter
from datetime import date
from datetime import timedelta
from dateutil.parser import parse

def make_histogram(innerDict):
    x = np.arange(len(innerDict.keys()))
    y = innerDict.values()
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(1,1,1)
    ax.bar(x, y)
    ax.set_xticks(x)
    ax.set_xticklabels(innerDict.keys(), rotation=70)
    plt.show()

from peewee import *
from Email import Email

db = SqliteDatabase('emails.db')
db.connect()

# %%
N_CLUSTERS = 3
reduce_dimensionality = True
color_by_party = True
k_means = KMeans(n_clusters=N_CLUSTERS, init='k-means++', max_iter=100, n_init=1, verbose=True)
vectorizer = TfidfVectorizer(max_df=0.5, min_df=0.1, stop_words='english')
lsa = TruncatedSVD(2)

# %%
emails = np.array([email for email in Email.select()])
text = np.array([email.text() for email in emails])
parties = np.array([email.party for email in emails])
vectors = vectorizer.fit_transform(text)
if reduce_dimensionality == True:
    X = lsa.fit_transform(vectors)
else:
    X = vectors
# Out:
# /Users/atul/.pyenv/versions/2.7.8/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2499: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)

# %%
km = k_means.fit(X)
# Out:
# Initialization complete
# Iteration  0, inertia 5.649
# Iteration  1, inertia 4.338
# Iteration  2, inertia 4.311
# Iteration  3, inertia 4.293
# Iteration  4, inertia 4.282
# Iteration  5, inertia 4.270
# Iteration  6, inertia 4.268
# Iteration  7, inertia 4.266
# Iteration  8, inertia 4.264
# Iteration  9, inertia 4.263
# Converged at iteration 9

# %%
k_means_labels = k_means.labels_
k_means_cluster_centers = k_means.cluster_centers_
k_means_labels_unique = np.unique(k_means_labels)
terms = vectorizer.get_feature_names()

# %%
if reduce_dimensionality == False:
    order_centroids = k_means_cluster_centers.argsort()[:, ::-1]
    for i in range(N_CLUSTERS):
        print [(terms[ind], k_means_cluster_centers[i][ind]) for ind in order_centroids[i, :100]]
        print ""

# %%
for k in range(N_CLUSTERS):
    z = vectors.toarray()[k_means_labels == k]
    wordz_tfidf = [(terms[i], z[:,i].sum()) for i in range(z.shape[1])]
    wordz_tfidf = sorted(wordz_tfidf, key=lambda x: x[1], reverse=True )
    print wordz_tfidf[:100]
    print ""
# Out:
# [(u'organization', 15.635383981290296), (u'elect', 15.465088480939984), (u've', 14.263764690870307), (u'2014', 13.79865592646771), (u'contributions', 12.257523324297168), (u'deductible', 12.080733734927589), (u'gifts', 11.995500373992131), (u'tax', 11.995500373992131), (u'chip', 10.715569870344501), (u'deadline', 9.6589846751788606), (u'just', 9.2739641904095222), (u'want', 8.9914551763289978), (u'help', 8.809623038348013), (u'online', 8.6857351505780755), (u'donate', 8.2800637988606667), (u'important', 8.0434906495996614), (u'election', 7.9805818885032496), (u'ideas', 7.7844992381949139), (u'supporting', 7.7639835846159944), (u'harder', 7.7342689709856707), (u'involved', 7.6825809896470814), (u'send', 7.6751151139632583), (u'leave', 7.6131602037082491), (u'comments', 7.
'win', 10.564826774435137), (u'support', 10.495919807284613), (u'days', 10.205839536048892), (u'american', 10.114288648770934), (u'challenge', 10.068398719722667), (u'double', 9.7260700841923846), (u'reince', 9.457631944961344), (u'just', 9.1981015331093054), (u'matching', 9.0976601949819909), (u'year', 9.0888333089325606), (u'voters', 9.0815676609100322), (u'donation', 8.7465034646404476), (u'signed', 8.6303811105140689), (u'time', 8.5277623068354451), (u'online', 8.5156801962297966), (u'add', 8.468937676665119), (u'impact', 8.401756378396863), (u'critical', 8.211067516001151), (u'voter', 8.1667541412814195), (u'new', 8.1215527145365236), (u'community', 8.061267781277337), (u'right', 7.8963209402801331), (u'receive', 7.8246311382335074), (u'donors', 7.8046134096893098), (u'doubled', 7.7818820471062073), (u'director', 7.7333246493171401), (u'group', 7.4669727484543023), (u'candidates', 7.3222754473985958), (u'help', 7.3085759362247265), (u'chance', 7.1184244695087049), (u'sure', 7.1132078752116303), (u'people', 6.8291566171194908), (u'years', 6.8184457804291476), (u'races', 6.6861995888874644), (u'chief', 6.5723332145296443), (u'left', 6.5582303848708996), (u'polls', 6.5518148621191887), (u'deadline', 6.4571880247526394), (u've', 6.2862825788340899), (u'party', 6.2409101975074552), (u'states', 6.234933967845862), (u'midnight', 6.1562141341555101), (u'november', 6.1561340897099051), (u'let', 6.0872625289325182), (u'contribution', 6.0016841879413274), (u'control', 5.8662868116264377), (u'fundraising', 5.8338258564618073), (u'elections', 5.7274278675477088), (u'close', 5.5561674624630584), (u'2014', 5.1817981501705344), (u'opportunity', 4.9031671430976793), (u'don', 4.8997003838528608), (u'elect', 4.851438234694621), (u'going', 4.819470954436925), (u'want', 4.1296847517077246), (u'll', 4.0242558220020488), (u'important', 4.0020674997018277), (u'great', 3.9443450016271115), (u'winning', 3.891296071782818), (u'record', 3.8160280833802669), (u'recent', 3.4121766413535877), (u'hard', 3.3034378227872345), (u'chip', 2.9534840902004937), (u'count', 2.9282955747327861), (u'thank', 2.6493559128032276), (u'contributing', 2.6328078749662414), (u'50', 2.6294951415610743), (u'step', 2.5871184325891696), (u'official', 2.5542455543549734), (u'18', 2.4136123363107185), (u'barack', 2.391133190934204), (u'contributions', 2.3529638815070273), (u'tax', 2.3355599911139322), (u'000', 2.3108586756088121), (u'gifts', 2.19869404914748), (u'deductible', 2.0690002809519226), (u'14', 2.0250124572500079), (u'friend', 1.9804639090194116), (u'10', 1.869981847695305), (u'united', 1.3110142399058162)]

# %%
if reduce_dimensionality == True:
    mpld3.enable_notebook()
    fig,ax = plt.subplots(figsize=(15,10))
    
    ph = {}
    ph_counter = 0
    def add_labels(fig, boolmap, points):
            global ph_counter
            labels = []
            for email in emails[boolmap]:
                ph[ph_counter] = email.politicalnewsbot_link()
                labels.append(str(ph_counter) + " " + email.message_id + " " + email.message_labels + " " + email.party)
                ph_counter += 1

            tooltip = plugins.PointHTMLTooltip(points[0], labels, voffset=10, hoffset=10)
            plugins.connect(fig, tooltip)
            urls = [email.politicalnewsbot_link() for email in emails[boolmap]]
            # plugins.connect(fig, ClickInfo(points[0], urls))

    if color_by_party == True:
        for party, col in zip(['DEM', 'REP'], ['blue', 'red']):
            my_members = parties == party
            points = ax.plot(X[my_members, 0], X[my_members, 1], 'w', markerfacecolor=col, marker='.', label='Party %s' % party )
            
            add_labels(fig, parties == party, points)
        
        for k in range(N_CLUSTERS):
            cluster_center = k_means_cluster_centers[k]
            centers = ax.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor='black', markeredgecolor='k', markersize=6)

    else:
        colors = [(random.random(), random.random(), random.random()) for x in range(N_CLUSTERS)]
        for k, col in zip(range(N_CLUSTERS), colors):
            my_members = k_means_labels == k
            cluster_center = k_means_cluster_centers[k]
            points = ax.plot(X[my_members, 0], X[my_members, 1], 'w', markerfacecolor=col, marker='.', label='Cluster %i' % k)
            centers = ax.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col, markeredgecolor='k', markersize=6)

            add_labels(fig, k_means_labels == k, points)

    ax.set_title('KMeans')
    ax.set_xticks(())
    ax.set_yticks(())
    ax.legend()
    ph_counter=0

# %%
mpld3.disable_notebook()

# %%
labels = ['CATEGORY_PROMOTIONS', 'CATEGORY_UPDATES', 'IMPORTANT', 'INBOX', 'UNREAD']
label_histogram = []
for k in range(N_CLUSTERS):
    innerDict = dict.fromkeys(labels, 0)
    for email in emails[k_means_labels == k]:
        current_labels = eval(email.message_labels)
        for label in current_labels:
            if label in innerDict:
                innerDict[label] = innerDict[label]+1
            else:
                innerDict[label] = 0

    label_histogram.append(innerDict)
label_histogram
# Out:
# [{'CATEGORY_PROMOTIONS': 106,
#   'CATEGORY_UPDATES': 0,
#   'IMPORTANT': 62,
#   'INBOX': 106,
#   'UNREAD': 37},
#  {'CATEGORY_PROMOTIONS': 44,
#   'CATEGORY_UPDATES': 0,
#   'IMPORTANT': 27,
#   'INBOX': 44,
#   'UNREAD': 0},
#  {'CATEGORY_PROMOTIONS': 71,
#   'CATEGORY_UPDATES': 122,
#   'IMPORTANT': 119,
#   'INBOX': 193,
#   'UNREAD': 43}]

# %%
make_histogram(label_histogram[0])

# %%
make_histogram(label_histogram[1])

# %%
print "\n".join([email.politicalnewsbot_link() for email in emails[k_means_labels == 1]])
# Out:
# https://mail.google.com/mail/u/2/#inbox/148f7df0a48fe0d7?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148f756366e6b609?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148f6cd547422e18?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148f694d25de5a23?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148f6069c40b83e7?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148f52bad7b5926f?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148f25c23f599a89?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148ecff2b9039193?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148e68d7ac0a0d55?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148e59ce33737a48?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148e1c677eaa3dd7?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148e12bb0a2fa117?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148d637f53857372?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148c9965806e8d49?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148c9399e2a55a91?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148c8deccdb6f9e8?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148c7b17b77bd673?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148c6e989df41aaa?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148c6569a547036a?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148c2c4438ebf4b9?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148c19c657093b22?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148bee9cf6567569?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148be16f86bf3d60?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148b96f74dbf281e?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148b748c255aabf4?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148b4ce75b15c63a?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148b404cb95abcf3?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/14860623ce607ff1?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/1485fbb00766b4bd?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/1485c0e27b6fa5d5?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/1485b15360ddb563?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/14856383d210c94e?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/148508e43345c644?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/1484c272c4952160?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/14846ce2c963c529?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/147f443dd24e106c?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/147f3d278035e6e5?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/147f100d469b4890?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/147eb86c407b3ef7?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/147e9f922d5a431f?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/147e485e92cd80b9?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/147e01d9607635bc?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/147db9b6d8480f24?authuser=politicalnewsbotnewyork@gmail.com
# https://mail.google.com/mail/u/2/#inbox/147d131e7aa0e114?authuser=politicalnewsbotnewyork@gmail.com
