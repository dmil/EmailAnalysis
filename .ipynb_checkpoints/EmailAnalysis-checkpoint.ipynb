# %%
# %matplotlib inline

from __future__ import division

import re, os, logging, sys, random, json, xml.etree.ElementTree 
from time import time

from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
from sklearn.cross_validation import cross_val_score
from sklearn import metrics
from sklearn.metrics import pairwise_distances

import numpy as np
from scipy.stats import mode
import matplotlib.pyplot as plt, mpld3
from mpld3 import plugins
# mpld3.enable_notebook()

from pprint import pprint
from operator import itemgetter
from datetime import date
from datetime import timedelta
from dateutil.parser import parse

def make_histogram(innerDict):
    x = np.arange(len(innerDict.keys()))
    y = innerDict.values()
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(1,1,1)
    ax.bar(x, y)
    ax.set_xticks(x)
    ax.set_xticklabels(innerDict.keys(), rotation=70)
    plt.show()

from peewee import *
from Email import Email

db = SqliteDatabase('emails.db')
db.connect()

# %%
N_CLUSTERS = 2
reduce_dimensionality = True
color_by_party = False
k_means = KMeans(n_clusters=N_CLUSTERS, init='k-means++', max_iter=100, n_init=1, verbose=True)
vectorizer = TfidfVectorizer(max_df=0.5, min_df=0.1, stop_words='english')
lsa = TruncatedSVD(2)

# %%
emails = np.array([email for email in Email.select()])
text = np.array([email.text() for email in emails])
parties = np.array([email.party for email in emails])
vectors = vectorizer.fit_transform(text)
if reduce_dimensionality == True:
    X = lsa.fit_transform(vectors)
else:
    X = vectors
# Out:
# /Users/atul/.pyenv/versions/2.7.8/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2499: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)

# %%
km = k_means.fit(X)
# Out:
# Initialization complete
# Iteration  0, inertia 9.347
# Iteration  1, inertia 7.830
# Converged at iteration 1

# %%
k_means_labels = k_means.labels_
k_means_cluster_centers = k_means.cluster_centers_
k_means_labels_unique = np.unique(k_means_labels)
terms = vectorizer.get_feature_names()

# %%
if reduce_dimensionality == False:
    order_centroids = k_means_cluster_centers.argsort()[:, ::-1]
    for i in range(N_CLUSTERS):
        print [(terms[ind], k_means_cluster_centers[i][ind]) for ind in order_centroids[i, :100]]
        print ""

# %%
for k in range(N_CLUSTERS):
    z = vectors.toarray()[k_means_labels == k]
    wordz_tfidf = [(terms[i], z[:,i].sum()) for i in range(z.shape[1])]
    wordz_tfidf = sorted(wordz_tfidf, key=lambda x: x[1], reverse=True )
    print wordz_tfidf[:100]
    print ""
# Out:
# [(u'senate', 33.585169207806018), (u'republican', 33.330490605019371), (u'election', 28.865120268951557), (u'today', 22.822859696834527), (u've', 20.550047269704397), (u'make', 20.521286733424748), (u'elect', 20.316526715634602), (u'donate', 19.894211352794755), (u'republicans', 19.021989945996847), (u'2014', 18.980454076638246), (u'rnc', 18.760886795466238), (u'just', 18.472065723518831), (u'action', 18.099360521677369), (u'support', 17.976460005595769), (u'online', 17.20141534680787), (u'day', 16.680247352239608), (u'politicalnews', 16.671842051444365), (u'vote', 16.657959342584654), (u'need', 16.51979860198395), (u'win', 16.442683371907322), (u'help', 16.118198974572742), (u'dead
3.945402246072327), (u'trip', 3.7130728314061567), (u'accommodations', 3.3813288757629474), (u'18', 3.3661558900816799), (u'dnc', 3.3557510952070073), (u'age', 3.1809230499468413), (u'applicable', 3.1809230499468413), (u'approximate', 3.1809230499468413), (u'attend', 3.1809230499468413), (u'district', 3.1809230499468413), (u'fifty', 3.1809230499468413), (u'lawful', 3.1809230499468413), (u'legal', 3.1809230499468413), (u'nights', 3.1809230499468413), (u'older', 3.1809230499468413), (u'open', 3.1809230499468413), (u'package', 3.1809230499468413), (u'payment', 3.1809230499468413), (u'prize', 3.1809230499468413), (u'prizes', 3.1809230499468413), (u'prohibited', 3.1809230499468413), (u'retail', 3.1809230499468413), (u'sponsor', 3.1809230499468413), (u'tickets', 3.1809230499468413), (u'void', 3.1809230499468413), (u'columbia', 3.157879644856616), (u'depend', 3.157879644856616), (u'eligibility', 3.157879644856616), (u'following', 3.157879644856616), (u'improve', 3.157879644856616), (u'law', 3.1353318354864235), (u'permanent', 3.1353318354864235), (u'restrictions', 3.1353318354864235), (u'round', 3.1353318354864235), (u'subject', 3.1281569174985009), (u'citizens', 3.1132587522851782), (u'twice', 3.1132587522851782), (u'value', 3.0916408167907581), (u'chances', 3.0496979147588759), (u'additional', 3.029339358065982), (u'odds', 3.029339358065982), (u'necessary', 3.0093686070835259), (u'number', 3.0093686070835259), (u'united', 3.0093686070835259), (u'click', 2.9705333256335047), (u'signup', 2.9390829801674956), (u'win', 2.8866884095533454), (u'opportunity', 2.8707294141024176), (u'50', 2.8281545456129304), (u'official', 2.8116434527835361), (u'count', 2.7385495343803439), (u'receive', 2.5956185658389468), (u'barack', 2.3893876687709219), (u'contribution', 2.3207562922199698), (u'll', 2.3104991160696038), (u'new', 2.1852032410361093), (u'000', 2.1603718425450946), (u'majority', 2.0136835668936928), (u'deductible', 1.8575475302301638), (u'gifts', 1.8444419505052232), (u'tax', 1.8444419505052232), (u'contributions', 1.8314981721967398), (u'chance', 1.8201613070119114), (u'day', 1.6686974792360172), (u'organization', 1.4435261331283957), (u'2014', 1.4308869841184686), (u've', 1.2041531482614942), (u'just', 1.1877072244532654), (u'stay', 1.1821892134390581), (u'chip', 1.1629627186163762), (u'friend', 1.1266579997468922), (u'want', 1.0458526739949021), (u'party', 1.0125999096816662), (u'don', 0.99948665339384546), (u'love', 0.95275400454203052), (u'today', 0.95249850402520053), (u'make', 0.91293215397534044), (u'hear', 0.90540922816864344), (u'important', 0.8709668749698054), (u'send', 0.79073902517979811), (u'supporting', 0.78982492530870418), (u'leave', 0.78294872073877753)]

# %%
if reduce_dimensionality == True:
    mpld3.enable_notebook()
    fig,ax = plt.subplots(figsize=(15,10))

    def add_labels(fig, boolmap, points):
            labels = []
            for email in emails[boolmap]:
                labels.append(email.message_id + " " + email.message_labels + " " + email.party)
            tooltip = plugins.PointHTMLTooltip(points[0], labels, voffset=10, hoffset=10)
            plugins.connect(fig, tooltip)

    if color_by_party == True:
        for party, col in zip(['DEM', 'REP'], ['blue', 'red']):
            my_members = parties == party
            points = ax.plot(X[my_members, 0], X[my_members, 1], 'w', markerfacecolor=col, marker='.', label='Party %s' % party )
            
            add_labels(fig, parties == party, points)
        
        for k in range(N_CLUSTERS):
            cluster_center = k_means_cluster_centers[k]
            centers = ax.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor='black', markeredgecolor='k', markersize=6)

    else:
        colors = [(random.random(), random.random(), random.random()) for x in range(N_CLUSTERS)]
        for k, col in zip(range(N_CLUSTERS), colors):
            my_members = k_means_labels == k
            cluster_center = k_means_cluster_centers[k]
            points = ax.plot(X[my_members, 0], X[my_members, 1], 'w', markerfacecolor=col, marker='.', label='Cluster %i' % k)
            centers = ax.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col, markeredgecolor='k', markersize=6)

            add_labels(fig, k_means_labels == k, points)

    ax.set_title('KMeans')
    ax.set_xticks(())
    ax.set_yticks(())
    ax.legend()

# %%
print "\n".join([email.politicalnewsbot_link() for email in emails[k_means_labels == 0]])
# Out:
# https://mail.google.com/mail/u/inbox/14943f0d66c05d35?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14943c68ccf03f20?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1494369b7abf9f09?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/149435cad2c707ac?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14942d8b0a5de577?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14942be134f257c2?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/149422fba8b840c0?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1493f4cc347467b7?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1493f10e6b1ed7b5?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1493ef1f21f3c167?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1493eb2d8caf1f94?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1493e3edd1194c42?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1493d9f467e45923?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1493d348bb659f9a?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1493d30aab6047e9?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1493ae547a5ee415?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1493a49dfa3e490d?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14939a5dfe94d2e2?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/149398743e9a5e03?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/149393e400647910?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1493925bb9936343?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14938e563ef21162?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14938421fb36a9d3?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/149376dc62816461?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1493584f0b051ce8?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14934b5a5148b130?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14934732a6123eea?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14934366e0863ce6?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14933f2ba5470842?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14933c4cabc68329?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1493385c2d473a34?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/149325075ab00b4f?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/149303df6b409d0f?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1492f953a101401b?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1492f39f81d59671?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1492eabf539f76b3?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1492e5b664be70dc?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1492dd404425cbd5?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1492d8ac2b57ccfb?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1492ac5105edbed7?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1492a87f222af7b2?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1492a09f8a04087b?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/149292d59322275b?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14928b117cd99a8d?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14928819e4e5b138?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1492567536fa016c?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14924c40df55ec30?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/149242058ca0d711?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14923dff9d46b7a5?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14923d406ef8d9d1?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1492383b43ab5e54?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1491fb63dda2eb9e?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1491f660d1840e0a?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1491ed63f5ea7ee3?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1491e1a0bfe02b5a?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1491b1f29e0a49d9?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1491afb876f8e925?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1491a6d5bb713b74?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14919f6e2900b499?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14918ef90816c590?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14916d68c01217e0?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14916b12528bdc6c?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1491629ba73d251c?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14915f4336869038?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14915d51e8ac1b25?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1491561b399a897f?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/149149cb0f0c32a9?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/149147cfc7261979?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/149143ebc011fa27?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14913f9b35bf0d31?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/149115045820b1d9?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14910cbd4b53ba3e?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/149108b2d11e1a6d?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14910680b706cbb9?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1491009c922a313e?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1490faf21c7bf30c?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1490f796761f9f0a?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1490ecf57ce0044b?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1490ea340869a72b?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1490c0851088bc35?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1490beff7068d2b8?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/
authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1487a92518da579f?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14879bd16b3ddb27?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14876c86d937a09b?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/148765dc1d2834d8?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14876168f5d88bd9?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14874e3c0720dd54?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14874979af833b65?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1487128c4cba23a0?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14870a80a29a408b?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14870217bbd0b53d?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1486f4afca6bef1b?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1486b57ced30ff6c?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1486afe44414d347?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1486a595378ecfd4?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14869a3e3faa915a?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/148614255e0c0692?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14860b8803343538?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1485fdb22c6336d5?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1485cc2ac677b81e?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1485c1be7a30f984?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14857390aa62f6c1?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14855786444c7df6?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1484b777d1fb8eec?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1484b223175910d5?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1484808f26df12f5?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/148479fbbc415fa8?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/148462ccfaec0d88?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/148460a8d0b5acb5?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14842f62464f58fb?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/148421443774402d?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/148420d1a44759d2?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14840e20fe0731c0?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1483de762c1249a3?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1483d36a00feb84b?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1483bc04258c2524?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/148380574b6059cd?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14836933d8c2e70a?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/148316c802693036?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1482ebf5499c90a9?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1482e25d38847772?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1482d414cd74850c?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1482d308b9c21eee?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1482c3a7b542e97e?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1482c35773488a2c?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/148295f31709346e?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14828987fbf5f900?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1482835c7c3e8d0f?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14827fcc7bb5800d?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14827b5d4ff84962?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14826d76958a05ab?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1482429981a99532?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/148238935598761e?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/148223e5d47e2632?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14821a315d6f3cf3?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1481ef53416e929a?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1481d84da69d3e0e?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1481cf2bb6728723?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1481921c161d1b39?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14817b46047ff893?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/148140b59f280d77?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/148137be928bc199?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14812a9f60de3117?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1480fd60745df898?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1480ef06edaf6d15?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/1480d816bf9b98e1?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/148095d329a0cc10?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/148047666bcef44c?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/148041ccecb77bcb?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14803545da593b62?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147fead01627d4cd?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147f9832b427a42a?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147f39215611ecd5?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147ee8b600a6b6b8?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147ee7a078470234?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147e94e64474d360?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147df7e7feb10264?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147d9e7230e81bfa?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147d6a390081fbc6?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147d5804673af0e5?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147d458a6d29133a?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147cf9308467aced?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147ca65a409022c5?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147c55089234e363?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147c0495baeaa291?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147bbe0bb854a324?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147b672932aa046c?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147b0a872fef532d?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147a46e406a8bdbe?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/147a1088899bede5?authuser=politicalnewsbot@gmail.com
# https://mail.google.com/mail/u/inbox/14791730288d96a7?authuser=politicalnewsbot@gmail.com

# %%
labels = ['CATEGORY_PROMOTIONS', 'CATEGORY_UPDATES', 'IMPORTANT', 'INBOX', 'UNREAD']
label_histogram = []
for k in range(N_CLUSTERS):
    innerDict = dict.fromkeys(labels, 0)
    for email in emails[k_means_labels == k]:
        current_labels = eval(email.message_labels)
        for label in current_labels:
            if label in innerDict:
                innerDict[label] = innerDict[label]+1
            else:
                innerDict[label] = 0

    label_histogram.append(innerDict)
label_histogram
# Out:
# [{'CATEGORY_PROMOTIONS': 177,
#   'CATEGORY_UPDATES': 122,
#   'IMPORTANT': 181,
#   'INBOX': 299,
#   'UNREAD': 80},
#  {'CATEGORY_PROMOTIONS': 44,
#   'CATEGORY_UPDATES': 0,
#   'IMPORTANT': 27,
#   'INBOX': 44,
#   'UNREAD': 0}]

# %%
make_histogram(label_histogram[0])

# %%
make_histogram(label_histogram[1])
